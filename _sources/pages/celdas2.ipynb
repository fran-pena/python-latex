# %% [markdown]
# # Uso de variables de otras celdas de código

# %%
# %store -r c

# %% [markdown]
# En una celda de código se carga la variable _c_ con:
# ```python
# %store -r c
# ```
#
# La celda puede tener etiqueta _hide-input_ si se quiere que no se muestre el código anterior.
#
# La variable puede ser usada a continuación y el resultado se mostrará tras construirse el Jupyter Book en HTML, según lo indicado en el {doc}`Apéndice <apendice1>`.

# %%
d = 2*c

# %% [markdown]
# El resultado puede indicarse en una celda de código con etiqueta _hide-input_ para evitar mostrar el código que lo genera:

# %%
print('Resultado: ', d)
# Out:
# Margen:  40
